# %% [markdown]
# **هێنانی کتێبخانەی بەکار هاتوو**

# %%
from IPython.display import Audio
from scipy.io import wavfile
import numpy as np

# %%
# !pip install -q transformers 
# !pip install soundfile
# !pip install librosa
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: soundfile in /home/soyanswartz/.local/lib/python3.10/site-packages (0.11.0)
# Requirement already satisfied: cffi>=1.0 in /home/soyanswartz/.local/lib/python3.10/site-packages (from soundfile) (1.15.1)
# Requirement already satisfied: pycparser in /home/soyanswartz/.local/lib/python3.10/site-packages (from cffi>=1.0->soundfile) (2.21)
# Defaulting to user installation because normal site-packages is not writeable
# Collecting librosa
#   Downloading librosa-0.9.2-py3-none-any.whl (214 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.3/214.3 KB 879.0 kB/s eta 0:00:00 kB/s eta 0:00:01:01
# Collecting audioread>=2.1.9
#   Downloading audioread-3.0.0.tar.gz (377 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 377.0/377.0 KB 3.7 MB/s eta 0:00:003.6 MB/s eta 0:00:01
#   Preparing metadata (setup.py) ... done
# Collecting pooch>=1.0
#   Downloading pooch-1.6.0-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 KB 7.8 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.2.0 in /home/soyanswartz/.local/lib/python3.10/site-packages (from librosa) (1.7.3)
# Requirement already satisfied: scikit-learn>=0.19.1 in /home/soyanswartz/.local/lib/python3.10/site-packages (from librosa) (1.1.2)
# Requirement already satisfied: decorator>=4.0.10 in /home/soyanswartz/.local/lib/python3.10/site-packages (from librosa) (5.1.1)
# Requirement already satisfied: joblib>=0.14 in /home/soyanswartz/.local/lib/python3.10/site-packages (from librosa) (1.2.0)
# Requirement already satisfied: soundfile>=0.10.2 in /home/soyanswartz/.local/lib/python3.10/site-packages (from librosa) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /home/soyanswartz/.local/lib/python3.10/site-packages (from librosa) (21.3)
# Requirement already satisfied: numpy>=1.17.0 in /home/soyanswartz/.local/lib/python3.10/site-packages (from librosa) (1.22.1)
# Collecting numba>=0.45.1
#   Using cached numba-0.56.4-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.5 MB)
# Collecting resampy>=0.2.2
#   Downloading resampy-0.4.2-py3-none-any.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 12.7 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting llvmlite<0.40,>=0.39.0dev0
#   Using cached llvmlite-0.39.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.6 MB)
# Requirement already satisfied: setuptools in /home/soyanswartz/.local/lib/python3.10/site-packages (from numba>=0.45.1->librosa) (65.4.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/soyanswartz/.local/lib/python3.10/site-packages (from packaging>=20.0->librosa) (3.0.9)
# Requirement already satisfied: requests>=2.19.0 in /home/soyanswartz/.local/lib/python3.10/site-packages (from pooch>=1.0->librosa) (2.28.1)
# Collecting appdirs>=1.3.0
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/soyanswartz/.local/lib/python3.10/site-packages (from scikit-learn>=0.19.1->librosa) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in /home/soyanswartz/.local/lib/python3.10/site-packages (from soundfile>=0.10.2->librosa) (1.15.1)
# Requirement already satisfied: pycparser in /home/soyanswartz/.local/lib/python3.10/site-packages (from cffi>=1.0->soundfile>=0.10.2->librosa) (2.21)
# Requirement already satisfied: certifi>=2017.4.17 in /home/soyanswartz/.local/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /home/soyanswartz/.local/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/soyanswartz/.local/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (1.26.12)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/soyanswartz/.local/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.1.1)
# Building wheels for collected packages: audioread
#   Building wheel for audioread (setup.py) ... done
#   Created wheel for audioread: filename=audioread-3.0.0-py3-none-any.whl size=23703 sha256=363372446d54eb7d02b94474f561597b2bc5edf1ef6ab95edce21e139a121be1
#   Stored in directory: /home/soyanswartz/.cache/pip/wheels/da/4b/39/c5f6c4ee93b43281dda4dab5ac5f2bdf9d11074d427493cd55
# Successfully built audioread
# Installing collected packages: appdirs, llvmlite, audioread, pooch, numba, resampy, librosa
# Successfully installed appdirs-1.4.4 audioread-3.0.0 librosa-0.9.2 llvmlite-0.39.1 numba-0.56.4 pooch-1.6.0 resampy-0.4.2

# %%
file_name='data/22.wav'

# %%
Audio(file_name)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ** نیشاندانی کات و سامپڵ رێیت  **

# %%
data = wavfile.read(file_name)
framerate = data[0]
sounddata = data[1]
time = np.arange(0,len(sounddata))/framerate
print('Sample rate:',framerate,'Hz')
print('Total time:',len(sounddata)/framerate,'s')
# Out:
# Sample rate: 48000 Hz
# Total time: 3.136 s

# %% [markdown]
# دابەزاندنی مۆدێڵێ زمانی کوردی

# %%
import soundfile as sf
import librosa
import torch
from transformers import Wav2Vec2ForCTC, Wav2Vec2Tokenizer
tokenizer = Wav2Vec2Tokenizer.from_pretrained("Akashpb13/Central_kurdish_xlsr")
model = Wav2Vec2ForCTC.from_pretrained("Akashpb13/Central_kurdish_xlsr")
# Out:
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'Wav2Vec2CTCTokenizer'.
# The class this function is called from is 'Wav2Vec2Tokenizer'.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %% [markdown]
# ناردنی فایلی دەنگی بۆ مۆدێلەکە و وەرگتنەوەی نوسین واتە گۆرینی بۆ **نوسین**

# %%
input_audio, _ = librosa.load(file_name, 
                            sr=16000)
input_values = tokenizer(input_audio, return_tensors="pt").input_values
logits = model(input_values).logits
predicted_ids = torch.argmax(logits, dim=-1)
transcription = tokenizer.batch_decode(predicted_ids)[0]

transcription
# Out:
# 'گڵۆپەکە هەڵ بکە'

# %%
if (transcription == 'گڵۆپەکە هەڵ بکە'):
    print("true")
# Out:
# true
